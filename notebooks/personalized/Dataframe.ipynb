# %% [markdown]
# # Convert NWB files to pandas Dataframes

# %%
# general python modules for scientific analysis
import sys, pathlib, os
import numpy as np

# add the python path:
sys.path.append('../../src')
from physion.analysis.dataframe import NWB_to_dataframe
from physion.utils import plot_tools as pt

# %%
filename = os.path.join(os.path.expanduser('~'), 'CURATED' , 'NDNF-December-2022', '2022_12_14-13-27-41.nwb')
data = NWB_to_dataframe(filename,
                        visual_stim_label='per-protocol',
                        #visual_stim_label='per-protocol-and-parameters',
                        #visual_stim_label='per-protocol-and-parameters-and-timepoints', #
                        subsampling = 10,
                        verbose=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 filename = os.path.join(os.path.expanduser('~'), 'CURATED' , 'NDNF-December-2022', '2022_12_14-13-27-41.nwb')
# ----> 2 data = NWB_to_dataframe(filename,
#       3                         visual_stim_label='per-protocol',
#       4                         #visual_stim_label='per-protocol-and-parameters',
#       5                         #visual_stim_label='per-protocol-and-parameters-and-timepoints', #
#       6                         subsampling = 10,
#       7                         verbose=False)
#
# File ~\Programming\In_Vivo\physion\notebooks\personalized\../../src\physion\analysis\dataframe.py:36, in NWB_to_dataframe(nwbfile, visual_stim_label, exclude_from_stim, exclude_from_timepoints, prestim_duration, poststim_duration, time_sampling_reference, normalize, subsampling, verbose)
#      12 def NWB_to_dataframe(nwbfile,
#      13                      visual_stim_label='per-protocol',
#      14                      exclude_from_stim=[],
#    (...)
#      20                      subsampling=None,
#      21                      verbose=True):
#      22     """
#      23     builds a pandas.DataFrame from a nwbfile
#      24     with a given time sampling reference
#    (...)
#      34
#      35     """
# ---> 36     data = read_NWB.Data(nwbfile, verbose=verbose)
#      38     if subsampling is None:
#      39         subsampling = 1
#
# File ~\Programming\In_Vivo\physion\notebooks\personalized\../../src\physion\analysis\read_NWB.py:37, in Data.__init__(self, filename, with_tlim, metadata_only, with_visual_stim, verbose)
#      35     print('starting reading [...]')
#      36 # try:
# ---> 37 self.io = pynwb.NWBHDF5IO(filename, 'r')
#      38 self.nwbfile = self.io.read()
#      40 self.read_metadata()
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\pynwb\__init__.py:309, in NWBHDF5IO.__init__(self, **kwargs)
#     307 if load_namespaces:
#     308     tm = get_type_map()
# --> 309     super().load_namespaces(tm, path, file=file_obj, driver=driver, aws_region=aws_region)
#     310     manager = BuildManager(tm)
#     312     # XXX: Leaving this here in case we want to revert to this strategy for
#     313     #      loading cached namespaces
#     314     # ns_catalog = NamespaceCatalog(NWBGroupSpec, NWBDatasetSpec, NWBNamespace)
#    (...)
#     317     # tm.copy_mappers(get_type_map())
#     318 else:
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\hdmf\backends\hdf5\h5tools.py:185, in HDF5IO.load_namespaces(cls, **kwargs)
#     174 """Load cached namespaces from a file.
#     175
#     176 If `file` is not supplied, then an :py:class:`h5py.File` object will be opened for the given `path`, the
#    (...)
#     180 :raises ValueError: if both `path` and `file` are supplied but `path` is not the same as the path of `file`.
#     181 """
#     182 namespace_catalog, path, namespaces, file_obj, driver, aws_region = popargs(
#     183     'namespace_catalog', 'path', 'namespaces', 'file', 'driver', 'aws_region', kwargs)
# --> 185 open_file_obj = cls.__resolve_file_obj(path, file_obj, driver, aws_region=aws_region)
#     186 if file_obj is None:  # need to close the file object that we just opened
#     187     with open_file_obj:
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\hdmf\backends\hdf5\h5tools.py:158, in HDF5IO.__resolve_file_obj(cls, path, file_obj, driver, aws_region)
#     156         if aws_region is not None:
#     157             file_kwargs.update(aws_region=bytes(aws_region, "ascii"))
# --> 158     file_obj = File(path, 'r', **file_kwargs)
#     159 return file_obj
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'C:\Users\laura.gonzalez\CURATED\NDNF-December-2022\2022_12_14-13-27-41.nwb', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
def min_max(array):
    return (array-array.min())/(array.max()-array.min())

def color(key):
    if 'Pupil' in key:
        return pt.plt.cm.Set1(0)
    elif 'Gaze' in key:
        return pt.plt.cm.Set1(4)
    elif 'Running' in key:
        return pt.plt.cm.Set1(1)
    elif 'Whisking' in key:
        return pt.plt.cm.Set1(3)
    elif 'VisStim' in key:
        return pt.plt.cm.Greys(np.random.uniform(0.2, .6))
    else:
        return pt.plt.cm.Greens(np.random.uniform(0.5, .8))
    
fig, ax = pt.plt.subplots(figsize=(8,10))
i = 0
for key in data.keys():
    if key !='time':
        c = color(key)
        ax.plot(data['time'], -i+.8*min_max(data[key].astype(float)), color=c, lw=1) # convert bool to float when needed
        ax.annotate(key+' ', (0, -i+.1), ha='right', color=c)
        i+=1
                
ax.axis('off');
